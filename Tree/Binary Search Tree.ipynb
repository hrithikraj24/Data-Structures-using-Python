# %%
class BinarySearchTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
    def add_child(self,data):
        if data == self.data:
            return
        
        if data < self.data:
            if self.left:
                self.left.add_child(data)
            else:
                self.left = BinarySearchTreeNode(data)
        else:
            if self.right:
                self.right.add_child(data)
            else:
                self.right = BinarySearchTreeNode(data)
                
    def search(self,val):
        if self.data == val:
            return True
        
        if val < self.data:
            return self.data.search(val)
        else:
            return False
        
        if val > self.data:
            return self.data.search(val)
        else:
            return False
        
    def min(self):
        if self.left is None:
            return self.data
        return self.left.min()
    
    def max(self):
        if self.right is None:
            return self.data
        return self.right.max()
        
    def in_order_traversal(self):
        elements = []
        
        if self.left:
            elements += self.left.in_order_traversal()
            
        elements.append(self.data)
        
        if self.right:
            elements += self.right.in_order_traversal()
        
        return elements
    
    def pre_order_traversal(self):
        elements = []
        
        elements.append(self.data)
        
        if self.left:
            elements += self.left.pre_order_traversal()
            
        if self.right:
            elements += self.right.pre_order_traversal()
        
        return elements
    
    def post_order_traversal(self):
        elements = []
        
        if self.left:
            elements += self.left.post_order_traversal()
            
        if self.right:
            elements += self.right.post_order_traversal()
        
        elements.append(self.data)
        
        return elements

def build_tree(elements):
    print("Building tree with these elements:",elements)
    root = BinarySearchTreeNode(elements[0])

    for i in range(1,len(elements)):
        root.add_child(elements[i])

    return root

if __name__ == '__main__':
    countries = ["India","Pakistan","Germany", "USA","China","India","UK","USA"]
    country_tree = build_tree(countries)

    print("UK is in the list? ", country_tree.search("UK"))
    print("Sweden is in the list? ", country_tree.search("Sweden"))
    print()

    numbers_tree = build_tree([17, 4, 1, 20, 9, 23, 18, 34])
    print("In order traversal gives this sorted list:",numbers_tree.in_order_traversal())
    print("Pre order traversal gives this sorted list:",numbers_tree.pre_order_traversal())
    print("Post order traversal gives this sorted list:",numbers_tree.post_order_traversal())
    print("Minimum : ",numbers_tree.min())
    print("Maximum : ",numbers_tree.max())
# Out:
# Building tree with these elements: ['India', 'Pakistan', 'Germany', 'USA', 'China', 'India', 'UK', 'USA']
# UK is in the list?  False
# Sweden is in the list?  False
#
# Building tree with these elements: [17, 4, 1, 20, 9, 23, 18, 34]
# In order traversal gives this sorted list: [1, 4, 9, 17, 18, 20, 23, 34]
# Pre order traversal gives this sorted list: [17, 4, 1, 9, 20, 18, 23, 34]
# Post order traversal gives this sorted list: [1, 9, 4, 18, 34, 23, 20, 17]
# Minimum :  1
# Maximum :  34

# %%
class BinarySearchTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
    def add_child(self,data):
        if data == self.data:
            return
        
        if data < self.data:
            if self.left:
                self.left.add_child(data)
            else:
                self.left = BinarySearchTreeNode(data)
        else:
            if self.right:
                self.right.add_child(data)
            else:
                self.right = BinarySearchTreeNode(data)
                
    def search(self,val):
        if self.data == val:
            return True
        
        if val < self.data:
            return self.data.search(val)
        else:
            return False
        
        if val > self.data:
            return self.data.search(val)
        else:
            return False
        
    def find_min(self):
        if self.left is None:
            return self.data
        return self.left.find_min()
    
    def find_max(self):
        if self.right is None:
            return self.data
        return self.right.find_max()
        
    def in_order_traversal(self):
        elements = []
        
        if self.left:
            elements += self.left.in_order_traversal()
            
        elements.append(self.data)
        
        if self.right:
            elements += self.right.in_order_traversal()
        
        return elements
    
    def delete_using_left(self,val):
        if val < self.data:
            if self.left:
                self.left = self.left.delete_using_left(val)
            
        elif val > self.data:
            if self.right:
                self.right = self.right.delete_using_left(val)
            
        else:
            if self.left is None and self.right is None:
                return None
            elif self.left is None:
                return self.right
            elif self.right is None:
                return self.right
            
            max_val = self.left.find_max()
            self.data = max_val
            self.left = self.left.delete_using_left(max_val)
            
        return self
    
    def delete_using_right(self,val):
        if val < self.data:
            if self.left:
                self.left = self.left.delete_using_right(val)
            
        elif val > self.data:
            if self.right:
                self.right = self.right.delete_using_right(val)
            
        else:
            if self.left is None and self.right is None:
                return None
            elif self.left is None:
                return self.right
            elif self.right is None:
                return self.right
            
            min_val = self.right.find_min()
            self.data = min_val
            self.right = self.right.delete_using_right(min_val)
            
        return self

def build_tree(elements):
    print("Building tree with these elements:",elements)
    root = BinarySearchTreeNode(elements[0])

    for i in range(1,len(elements)):
        root.add_child(elements[i])

    return root

if __name__ == '__main__':
    numbers_tree = build_tree([17, 4, 1, 20, 9, 23, 18, 34])
    numbers_tree.delete_using_left(20)
    print("After deleting 20 using Left side: ",numbers_tree.in_order_traversal())
    print()

    numbers_tree = build_tree([17, 4, 1, 20, 9, 23, 18, 34])
    numbers_tree.delete_using_right(9)
    print("After deleting 9 using Right side: ",numbers_tree.in_order_traversal())
    print()
    
    numbers_tree = build_tree([17, 4, 1, 20, 9, 23, 18, 34])
    numbers_tree.delete_using_right(17)
    print("After deleting 17 using Right side: ",numbers_tree.in_order_traversal())
# Out:
# Building tree with these elements: [17, 4, 1, 20, 9, 23, 18, 34]
# After deleting 20 using Left side:  [1, 4, 9, 17, 18, 23, 34]
#
# Building tree with these elements: [17, 4, 1, 20, 9, 23, 18, 34]
# After deleting 9 using Right side:  [1, 4, 17, 18, 20, 23, 34]
#
# Building tree with these elements: [17, 4, 1, 20, 9, 23, 18, 34]
# After deleting 17 using Right side:  [1, 4, 9, 18, 20, 23, 34]
